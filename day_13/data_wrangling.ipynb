# %% [markdown]
# # EDA (Exploratory Data Analysis)
# - It is a method to use `analyze` and `summarize` dataset.
# - In python we use pandas library to do EDA

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import dataset
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.shape
# Out:
# (891, 15)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
# summarize
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# find null values
df.isnull()
# Out:
#      survived  pclass    sex    age  sibsp  parch   fare  embarked  class  \
# 0       False   False  False  False  False  False  False     False  False
# 1       False   False  False  False  False  False  False     False  False
# 2       False   False  False  False  False  False  False     False  False
# 3       False   False  False  False  False  False  False     False  False
# 4       False   False  False  False  False  False  False     False  False
# ..        ...     ...    ...    ...    ...    ...    ...       ...    ...
# 886     False   False  False  False  False  False  False     False  False
# 887     False   False  False  False  False  False  False     False  False
# 888     False   False  False   True  False  False  False     False  False
# 889     False   False  False  False  False  False  False     False  False
# 890     False   False  False  False  False  False  False     False  False
#
#        who  adult_male   deck  embark_town  alive  alone
# ...

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum() / df.shape[0] * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
# finding unique values
df.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# Visualize nan values
sns.heatmap(df.isnull(), yticklabels=False, cbar=True, cmap='viridis')
# Out:
# <Axes: >

# %%
# dropping columns
print("Shape before dropping columns: ", df.shape)
df.drop(columns=['deck'], inplace=True)
print("Shape after dropping columns: ", df.shape)
# Out:
# Shape before dropping columns:  (891, 15)
# Shape after dropping columns:  (891, 14)

# %%
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
# Visualize and Explore
sns.countplot(x='survived', data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.barplot(data=df, x='survived', y='age', hue='who')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.countplot(x='pclass', data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='count'>

# %%
# Distribution of data
sns.histplot(data=df, x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=df, x='age', bins=5)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df['age'].hist(bins=30, color='darkred', alpha=0.7)
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
# always take categorical data in x axis  
sns.boxplot(data=df, x='class', y='age')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.boxplot(data=df, y='age', x='survived')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.boxplot(data=df, y='age', x='survived', hue='who')
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
# scatter plot
sns.scatterplot(data=df, x='age', y='fare')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(data=df, x='age', y='fare', hue='who')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.scatterplot(data=df, x='age', y='fare', hue='pclass')
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %%
sns.pairplot(data=df, hue='survived')

# %%
# stacked bar plot
# df.groupby(['pclass', 'sex'])['survived'].count()
df.groupby(['pclass', 'sex'])['survived'].mean()
# Out:
# pclass  sex
# 1       female    0.968085
#         male      0.368852
# 2       female    0.921053
#         male      0.157407
# 3       female    0.500000
#         male      0.135447
# Name: survived, dtype: float64

# %%
df.groupby(['pclass', 'sex'])['survived'].mean().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='pclass'>

# %%
df.groupby(['pclass', 'who'])['survived'].mean().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='pclass'>

# %%
df.groupby(['pclass', 'who'])['fare'].mean().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='pclass'>

# %%
# swarm plot
sns.swarmplot(data=df, x='pclass', y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>
# /home/idev/.local/lib/python3.10/site-packages/seaborn/categorical.py:3370: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df, x='survived', y='fare')
# Out:
# /home/idev/.local/lib/python3.10/site-packages/seaborn/categorical.py:3370: UserWarning: 58.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/idev/.local/lib/python3.10/site-packages/seaborn/categorical.py:3370: UserWarning: 28.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='survived', ylabel='fare'>
# /home/idev/.local/lib/python3.10/site-packages/seaborn/categorical.py:3370: UserWarning: 68.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/idev/.local/lib/python3.10/site-packages/seaborn/categorical.py:3370: UserWarning: 41.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(data=df, x='survived', y='age', hue='who', size=3)
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
# point plot
sns.catplot(data=df, x='pclass', y='fare', hue='embarked', kind='point')

# %%
# Relation of 2 numeric variables
sns.lmplot(data=df, x='age', y='fare')

# %%
sns.lmplot(data=df[df['fare']<300], x='age', y='fare')

# %%
sns.lmplot(data=df, x='age', y='fare', hue='who')
plt.ylim(0,300)
# Out:
# (0.0, 300.0)

# %%
# How to add a column to a dataframe and  make a age group
df['age_group'] = pd.cut(df['age'], 
                         bins=[0, 10, 18, 30, 50, 80], 
                         labels=['kids', 'child', 'young', 'middle age', 'old']
                         )

df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone   age_group
# 0    man        True  Southampton    no  False       young
# 1  woman       False    Cherbourg   yes  False  middle age
# 2  woman       False  Southampton   yes   True       young
# 3  woman       False  Southampton   yes  False  middle age
# 4    man        True  Southampton    no   True  middle age

# %%
df.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 120         0       2    male  21.0      2      0  73.5000        S  Second
# 115         0       3    male  21.0      0      0   7.9250        S   Third
# 791         0       2    male  16.0      0      0  26.0000        S  Second
# 24          0       3  female   8.0      3      1  21.0750        S   Third
# 345         1       2  female  24.0      0      0  13.0000        S  Second
# 362         0       3  female  45.0      0      1  14.4542        C   Third
# 357         0       2  female  38.0      0      0  13.0000        S  Second
# 98          1       2  female  34.0      0      1  23.0000        S  Second
# 359         1       3  female   NaN      0      0   7.8792        Q   Third
# 590         0       3    male  35.0      0      0   7.1250        S   Third
#
#        who  adult_male  embark_town alive  alone   age_group
# 120    man        True  Southampton    no  False       young
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'age_group'],
#       dtype='object')

# %%
df.groupby('age_group')['survived'].mean()
# Out:
# /tmp/ipykernel_7458/433783009.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['survived'].mean()
# age_group
# kids          0.593750
# child         0.426667
# young         0.355556
# middle age    0.423237
# old           0.343750
# Name: survived, dtype: float64

# %%
df.groupby('age_group')['survived'].mean().plot(kind='bar')
# Out:
# /tmp/ipykernel_7458/3562096312.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['survived'].mean().plot(kind='bar')
# <Axes: xlabel='age_group'>

# %%
df.groupby('age_group')['fare'].mean().plot(kind='bar')
# Out:
# /tmp/ipykernel_7458/1314158953.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('age_group')['fare'].mean().plot(kind='bar')
# <Axes: xlabel='age_group'>

# %%
sns.pairplot(data=df, hue='survived', vars=['age', 'fare', 'pclass'])

# %% [markdown]
# - survival - Survival (0 = No; 1 = Yes)
# - class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# - name - Name
# - sex - Sex
# - age - Age
# - sibsp - Number of Siblings/Spouses Aboard
# - parch - Number of Parents/Children Aboard
# - ticket - Ticket Number
# - fare - Passenger Fare
# - cabin - Cabin
# - embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# - boat - Lifeboat (if survived)
# - body - Body number (if did not survive and body was recovered)
#
# May this help you: https://data.world/nrippner/titanic-disaster-dataset

# %%
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male  embark_town alive  alone   age_group
# 0    man        True  Southampton    no  False       young
# ...

# %%
# add column of family size
df['family_size'] = df['sibsp'] + df['parch'] + 1

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone', 'age_group', 'family_size'],
#       dtype='object')

# %%
df.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...
