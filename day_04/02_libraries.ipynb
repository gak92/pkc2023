# %% [markdown]
# 1- pandas
# 2- numpy
# 3- matplotlib
# 4- seaborn
# 5- plotly
# 6- scipystats (scipy)
# 7- scikit-learn
# 8- streamlit

# %%
# pip install pandas numpy matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/idev/.local/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: numpy in /home/idev/.local/lib/python3.10/site-packages (1.26.1)
# Collecting matplotlib
#   Downloading matplotlib-3.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/idev/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/idev/.local/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.43.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 1.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 3.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: packaging>=20.0 in /home/idev/.local/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib) (9.0.1)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.7/301.7 KB 2.2 MB/s eta 0:00:000:00:010:00:01:01
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.43.1 kiwisolver-1.4.5 matplotlib-3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install seaborn plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 664.1 kB/s eta 0:00:000:00:01m eta 0:00:01
# Collecting plotly
#   Downloading plotly-5.17.0-py2.py3-none-any.whl (15.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in /home/idev/.local/lib/python3.10/site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: pandas>=1.2 in /home/idev/.local/lib/python3.10/site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/idev/.local/lib/python3.10/site-packages (from seaborn) (1.26.1)
# Requirement already satisfied: packaging in /home/idev/.local/lib/python3.10/site-packages (from plotly) (23.2)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/idev/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/idev/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/idev/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (9.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/idev/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/idev/.local/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/idev/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Installing collected packages: tenacity, plotly, seaborn
# Successfully installed plotly-5.17.0 seaborn-0.13.0 tenacity-8.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly as px

# %%
# plotting
sns.set_theme(style="whitegrid")

diamonds = sns.load_dataset("diamonds")
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="clarity", y="carat",
              color="b", order=clarity_ranking,
              width_method="linear", data=diamonds)
# Out:
# <Axes: xlabel='clarity', ylabel='carat'>
